# %% [markdown]
# ##### 🧷 Imports y variables definidas en el cuaderno 🧷

# %%
import time

referenced_sample_var1:str = "Hola a tod@s"
referenced_sample_var2:int = 5

print("Hola, soy un notebook llamado como referencia")
